# %%
#•	Write a program to input a string and display its length without using the len() function
string=str(input("Enter the String"))
len=-1
for i in string:
    len+=1
print("Length of the string is ",len)
# Out:
# Enter the String balaji
# Length of the string is  5

# %%
#•	Count the number of vowels, consonants, digits, spaces, and special characters in a given string. 
string=input("enter the String")
v=0
c=0
for i in string:
    if i=="a" or i=="e" or i=="i" or i=="o" or i=="u":
        v+=1
    else:
        c+=1
print("Vlvels is",v,"Consenents is",c)
# Out:
# enter the String balaji
# Vlvels is 3 Consenents is 3

# %%
#•	Reverse the given string without using built-in reverse functions. 
string=input("enter the String")
print("Reversed string",string[::-1])

# %%
#•	Check whether the entered string is a palindrome
string=input("enter the String")
if(string==string[::-1]):
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# enter the String madam
# Palindrome

# %%
#•	Count the number of uppercase and lowercase letters in a string. 
string=input("enter the String")
lower=0
upper=0
for i in string:
    if i.isupper():
        upper+=1
    else:
        lower+=1
print("Lower is",lower,"upper is ",upper)
# Out:
# enter the String Balaji
# Lower is 5 upper is  1

# %%
string=input("enter the String")
new_string=string.replace("a","e")
print(new_string)
# Out:
# enter the String balaji
# beleji

# %%
#Remove all spaces from the input string
string=input("enter the String")
print("Space removed",string.split(" "))
# Out:
# enter the String balaji ramraje
# Space removed ['balaji', 'ramraje']

# %%
#•	Find the number of times a specified character appears in a string. 
string=input("enter the String")
count=string.count("a")
print(count)
# Out:
# enter the String balaji
# 2

# %%
#Print the first and last character of a string
string=input("enter the String")
print("First",string[0])
print("Last",string[-1])
# Out:
# enter the String balaji
# First b
# Last i

# %%
#•	Display each character of a string along with its ASCII value.
text = "Python"

for char in text:
    print(f"Character: {char} -> ASCII: {ord(char)}")
# Out:
# Character: P -> ASCII: 80
# Character: y -> ASCII: 121
# Character: t -> ASCII: 116
# Character: h -> ASCII: 104
# Character: o -> ASCII: 111
# Character: n -> ASCII: 110

# %%
del len

# %%
#Find the longest word in a given sentence. 
sentence = input("Enter a sentence: ")

words = sentence.split()

longest = words[0]

for word in words:
    if len(word) > len(longest):
        longest = word

print("Longest word:", longest)
print("Length:", len(longest))
# Out:
# Enter a sentence:  balaji ram
# Longest word: balaji
# Length: 6

# %%
#a.	Find the shortest word in a sentence
sentence = input("Enter a sentence: ")

words = sentence.split()

shortest = words[0]

for word in words:
    if len(word) < len(shortest):
        shortest = word

print("Shortest word:", shortest)
print("Length:", len(shortest))
# Out:
# Enter a sentence:  balaji ram
# Shortest word: ram
# Length: 3

# %%
#a.	Convert the first letter of every word to uppercase. 
sentence = input("Enter a sentence: ")

words = sentence.split()

for i in range(len(words)):
    words[i] = words[i].capitalize()

result = " ".join(words)

print(result)

# %%
#a.	Print all duplicate characters in a string
string = input("Enter a string: ")

printed = ""

for ch in string:
    if string.count(ch) > 1 and ch not in printed:
        print(ch)
        printed += ch

# %%
#a.	Display the frstring = input("Enter a string: ")

printed = ""

for ch in string:
    if ch not in printed:
        print(ch, ":", string.count(ch))
        printed += chequency of every character in a string.

# %%
#a.	Check whethstring1 = input("Enter first string: ")
string2 = input("Enter second string: ")

if sorted(string1) == sorted(string2):
    print("Strings are Anagrams")
else:
    print("Strings are Not Anagrams")er two strings are anagrams.

# %%
#a.	Remove duplicate characters while maintaining the original order. 
string = input("Enter a string: ")

result = ""

for ch in string:
    if ch not in result:
        result += ch

print("String after removing duplicates:", result)

# %%
#a.	Check whether a given substring exists in the main string.
string = input("Enter the main string: ")
substring = input("Enter the substring: ")

if substring in string:
    print("Substring exists")
else:
    print("Substring does not exist")

# %%
#a.	Count how many times a specific word appears in a sentence. 
sentence = input("Enter a sentence: ")
word = input("Enter the word to search: ")

words = sentence.split()

count = 0

for w in words:
    if w == word:
        count += 1

print("Occurrences:", count)

# %%
#21
password = input("Enter the password: ")

upper = False
lower = False
digit = False
special = False

for ch in password:
    if ch.isupper():
        upper = True
    elif ch.islower():
        lower = True
    elif ch.isdigit():
        digit = True
    else:
        special = True

if len(password) >= 8 and upper and lower and digit and special:
    print("Valid Password")
else:
    print("Invalid Password")

# %%
#22
string = input("Enter a string: ")

count = 1

for i in range(len(string)):
    if i < len(string) - 1 and string[i] == string[i + 1]:
        count += 1
    else:
        print(string[i] + str(count), end="")
        count = 1

# %%
#•	Compress repeated characters and return the original string if compression does not reduce the length
string = input("Enter a string: ")

result = ""
count = 1

for i in range(len(string)):
    if i < len(string) - 1 and string[i] == string[i + 1]:
        count += 1
    else:
        result = result + string[i] + str(count)
        count = 1

if len(result) < len(string):
    print("Compressed String:", result)
else:
    print("Original String:", string)

# %%
#Find the character with the highest frequency
string = input("Enter a string: ")

max_char = string[0]

for ch in string:
    if string.count(ch) > string.count(max_char):
        max_char = ch

print("Most frequent character:", max_char)
print("Frequency:", string.count(max_char))

# %%
#•	Find the second most frequently occurring character. 
string = input("Enter a string: ")

freq = {}

for ch in string:
    freq[ch] = string.count(ch)

first = 0
second = 0
first_char = ""
second_char = ""

for ch in freq:
    if freq[ch] > first:
        second = first
        second_char = first_char
        first = freq[ch]
        first_char = ch
    elif freq[ch] > second and freq[ch] != first:
        second = freq[ch]
        second_char = ch

if second_char == "":
    print("No second most frequent character")
else:
    print("Second most frequent character:", second_char)
    print("Frequency:", second)

# %%
#•	Encrypt and decrypt a message using the Caesar Cipher algorithm
text = input("Enter the message: ")
shift = int(input("Enter the shift value: "))

result = ""

for ch in text:
    if ch.isupper():
        result += chr((ord(ch) - 65 + shift) % 26 + 65)
    elif ch.islower():
        result += chr((ord(ch) - 97 + shift) % 26 + 97)
    else:
        result += ch

print("Encrypted message:", result)

# %%
\
